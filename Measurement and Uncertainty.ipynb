# %%
from random import random
from scipy.stats import powerlaw
import numpy as np
from numpy import mean, arange, std, exp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def computeEntity(p):
    if random() < p:
        return 1
    else:
        return 0
    
def bernouliMeasurement(iterations, sampleSize, probability):
    x=[]
    for i in range(iterations):
        y=[]
        for j in range(sampleSize):
            y.append(computeEntity(probability))
        x.append(round(mean(y),3))
    return x

def bernoulieProb(sampleSize):
    resultX=[]
    resultY=[]
    for p in arange(0.01,0.99, 0.01):
        resultY.append(std(bernouliMeasurement(100, sampleSize, p)))
        resultX.append(p)
    return resultX, resultY

def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %%
res10=bernouliMeasurement(1000, 10, 0.5);
res100=bernouliMeasurement(1000, 100, 0.5);

# %%
plt.hist(res10)
plt.hist(res100)
plt.show()

# %%
x, y = bernoulieProb(100)

# %%
plt.plot(x, y)
plt.ylabel('Standard Deviation')
plt.xlabel('Probability')
plt.show()

# %%
plt.plot(np.linspace(-3, 3, 120), gaussian(np.linspace(-3, 3, 120), 0, 1))
plt.show()

# %%
zz=np.linspace(0,1,12)

# %%
 r = powerlaw.rvs(2, size=1000)

# %%
fig, ax = plt.subplots(1, 1);

# %%
ax.hist(r, normed=True, histtype='stepfilled', alpha=0.2)
plt.show()

# %%
r
# Out:
# array([ 0.97484593,  0.14607556,  0.92768976,  0.91523893,  0.76831409,
#         0.9406995 ,  0.57523368,  0.9250327 ,  0.90244546,  0.96225768,
#         0.63812891,  0.60590707,  0.85313845,  0.73154788,  0.85530039,
#         0.77333337,  0.57251061,  0.51381951,  0.4156806 ,  0.93715469,
#         0.97778792,  0.91176292,  0.3667292 ,  0.23564977,  0.85801543,
#         0.35899347,  0.92448225,  0.78001281,  0.53678572,  0.63636537,
#         0.79857433,  0.52039239,  0.73862811,  0.88273332,  0.75267806,
#         0.81663731,  0.99391045,  0.80677601,  0.72207773,  0.70529158,
#         0.97228349,  0.89985335,  0.90308409,  0.0305027 ,  0.83286697,
#         0.16534774,  0.6584652 ,  0.88559303,  0.25417561,  0.72053926,
#         0.86670267,  0.89362188,  0.91581078,  0.8356685 ,  0.84795401,
#         0.9571242 ,  0.60634325,  0.5960339 ,  0.54768567,  0.82778072,
#         0.49353422,  0.86108083,  0.98005647,  0.23054089,  0.3930754 ,
# ...
